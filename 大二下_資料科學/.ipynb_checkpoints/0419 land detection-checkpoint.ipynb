# %% [markdown]
# # 自走車 Lane detecture

# %% [markdown]
# # gaussian blurring
# denoise
# remove the noise
# 讓他模糊 光滑 把雜點去除 卻也更模糊
#
# digital image processing
# image composed of pixels(basic unit of img)
# each image is matrix
# 黑白圖: binary img 只有 黑或白
# 灰階圖: grayscale img 色階介於[0,255]
# 彩色圖: colored img 有三個matrices 分別存 RGB 疊三層
#
# 給定原圖I (I1*I2)跟filter K (K1*K2)(smaller matrix)
# 做inner product 得到略小的新圖 (I1-Ki+1)*(I2-K2+1)
#
# 根據filter K的不同可以得到效果

# %%
import cv2
img = cv2.imread('d:/road.jpg')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
blur1 = cv2.GaussianBlur(gray,(3,3),0)
#用3*3的矩陣取平均
blur2 = cv2.GaussianBlur(gray,(13,13),0)
#用13*13的矩陣取平均
#cv2.imshow('Normal',img)
#cv2.imshow('Gray',gray)
cv2.imshow('Blur1',blur1)
cv2.imshow('Blur2',blur2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
img = cv2.imread('d:/road.jpg')
blur3 = cv2.GaussianBlur(img,(3,3),0)
#用3*3的矩陣取平均
cv2.imshow('Normal',img)
cv2.imshow('Blur3',blur3)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # edge detection
# edge:sudden change of the pixel value
# 比方說左邊是黃色右邊是藍色 兩色塊中間的gap就是edge
#
# canny edge detection
# 研究gradient(梯度) 要有巨大梯度差才會偵測為edge

# %%
import cv2
def get_edge(img):
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray,(13,13),0)
    canny = cv2.Canny(blur,50,150)
    #第二個參數是下界 第三個是上界 
    #超過上界的一定是邊 介於中間但兩邊連接的點都高於上界也是邊
    #低於下界一定不是邊
    canny2 = cv2.Canny(blur,150,250)
    cv2.imshow('Canny2',canny2)
    return canny

img = cv2.imread('d:/road.jpg')
edge = get_edge(img)
cv2.imshow('Edge',edge)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
def get_edge(img):
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray,(13,13),0)
    canny = cv2.Canny(blur,30,150)
    #第二個參數是下界 第三個是上界 
    #超過上界的一定是邊 介於中間但兩邊連接的點都高於上界也是邊
    #低於下界一定不是邊
    return canny

img1 = cv2.imread('d:/blur.jpg')
blur = get_edge(img1)
cv2.imshow('blur',blur)
img2 = cv2.imread('d:/clearcar.jpeg')
clear = get_edge(img2)
cv2.imshow('clear',clear)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # ROI
# 只想看某部分
# 要先Define 你想看哪
# 怎麼挑出你要看的東西的座標勒?
#
# 用spyder 開matplotlib.pyplot 可以輕鬆用滑鼠找到座標
# numpy: numeric operation of python
# 讓你很有效率的處理陣列運算
#
# 用一堆座標產生遮罩mask
#
# 接著用logical operator bitwise and 遮起來

# %%
import cv2
import matplotlib.pyplot as plt
def get_edge(img):
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray,(13,13),0)
    canny = cv2.Canny(blur,80,150)
    return canny

img = cv2.imread('d:/road.jpg')
edge = get_edge(img)
plt.imshow(edge)
plt.show()

# %%
import cv2
import numpy as np
def get_edge(img):
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray,(13,13),0)
    canny = cv2.Canny(blur,50,150)
    return canny
img = cv2.imread('d:/road.jpg')
edge = get_edge(img)
mask = np.zeros_like(edge)
#跟你的圖一樣大的黑黑的圖
points=np.array([[[146,539],[781,539],[515,417],[296,397]]])
#這四個點是你用matplotlib.pyplot發現的
cv2.fillPoly(mask,points,255)
cv2.imshow('Mask',mask)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#EXERCISE
import cv2
import numpy as np
def get_edge(img):
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray,(13,13),0)
    canny = cv2.Canny(blur,50,150)
    return canny
img = cv2.imread('d:/road.jpg')
edge = get_edge(img)
mask = np.zeros_like(edge)
points=np.array([[[280,200],[265,230],[230,240],[255,260],[250,290],[280,275],[310,290],[305,260],[330,240],[295,230]]])
cv2.fillPoly(mask,points,255)
cv2.imshow('Mask',mask)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
def get_edge(img):
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray,(13,13),0)
    canny = cv2.Canny(blur,50,150)
    return canny
def get_roi(img):
    mask = np.zeros_like(img)
    points=np.array([[[146,539],[781,539],[515,417],[296,397]]])
    cv2.fillPoly(mask,points,255)
    cv2.imshow('Mask',mask)
    roi=cv2.bitwise_and(img,mask)
    return roi
img = cv2.imread('d:/road.jpg')
cv2.imshow('img',img)
edge = get_edge(img)
roi = get_roi(edge)
cv2.imshow('ROI',roi)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#EXERCISE
import cv2
import numpy as np
def get_roi(img):
    mask = np.zeros_like(img)
    points=np.array([[[145,0],[115,30],[110,80],[122,120],[128,118],[133,138],[137,149],[140,155],[160,170],[190,175]
                      ,[210,170],[222,155],[235,115],[245,85],[245,35],[215,0]]])
    cv2.fillPoly(mask,points,(255,255,255))
    roi=cv2.bitwise_and(img,mask)
    return roi
img = cv2.imread('d:/trump.jpg')
cv2.imshow('img',img)
roi = get_roi(img)
cv2.imshow('ROI',roi)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # determing best road segment
# hough transform
# 給定 xi,yi 找出一個 y=ax+b 使這最多的點點是在上面
# hough voting
# 把這些線都標在極座標上然後累積最多的就是我們要找的

# %%
import cv2
import numpy as np
def get_edge(img):
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray,(13,13),0)
    canny = cv2.Canny(blur,50,150)
    return canny
def get_roi(img):
    mask = np.zeros_like(img)
    points=np.array([[[146,539],[781,539],[515,417],[296,397]]])
    cv2.fillPoly(mask,points,255)
    roi=cv2.bitwise_and(img,mask)
    return roi
def draw_lines(img,lines):
    for line in lines:
        points = line.reshape(4,)
        x1,y1,x2,y2=points
        cv2.line(img,(x1,y1),(x2,y2),(0,0,255),3)
    return img
img = cv2.imread('d:/road.jpg')
edge = get_edge(img)
roi = get_roi(edge)
#hough transformation
lines = cv2.HoughLinesP(image=roi,
                       rho=3,
                       theta=np.pi/180,
                       threshold=60,
                       minLineLength = 40,
                       maxLineGap = 50)
print(lines)
if lines is not None:
    img = draw_lines(img,lines)
else:
    print('Cannot detect line segment')
    
cv2.imshow('Line',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [[[556 454 756 539]]
#
#  [[511 439 590 475]]
#
#  [[470 413 547 450]]
#
#  [[454 411 719 535]]
#
#  [[208 488 302 415]]
#
#  [[490 429 655 506]]
#
#  [[238 491 315 416]]]

# %% [markdown]
# # Linear Regression=> Least Square Method
# 找出 sum(y(head)-y(real))^2 最小
# numpy 的polyfit 可以幫你找出最適的

# %%
import numpy as np
#回傳係數
a,b=np.polyfit((0,5),(5,0),deg=1)
print(f'y={a}x+{b}')
# Out:
# y=-1.0x+4.999999999999998

# %%
#EXERCISE
import cv2
import numpy as np
def get_edge(img):
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray,(13,13),0)
    canny = cv2.Canny(blur,50,150)
    return canny
def get_roi(img):
    mask = np.zeros_like(img)
    points=np.array([[[146,539],[781,539],[515,417],[296,397]]])
    cv2.fillPoly(mask,points,255)
    roi=cv2.bitwise_and(img,mask)
    return roi
def draw_lines(img,lines):
    for line in lines:
        points = line.reshape(4,)
        x1,y1,x2,y2=points
        cv2.line(img,(x1,y1),(x2,y2),(0,0,255),3)
    return img
def get_avglines(lines):
    if lines is None:
        print('Cannot detect straight line segment')
        return None
    #肉眼分得出左右但電腦不會
    #左邊是左下右上=>斜率為正的是左邊
    #右邊是右下左上=>斜率為負的是右邊
    lefts=[]
    rights=[]
    for line in lines:
        points = line.reshape(4,)
        x1,y1,x2,y2=points
        slope,b=np.polyfit((x1,x2),(y1,y2),1)
        if slope>0:
            rights.append([slope,b])
        else:
             lefts.append([slope,b])
    if rights and lefts:
        #求兩邊的平均線
        right_avg = np.average(rights,axis=0)
        left_avg = np.average(lefts,axis=0)
        return np.array([right_avg,left_avg])
    else:
        print('Cannot detect two lines simultaneously')
        return None
#我只想截"路"的那一段而已 不想要無限延伸版本
def get_sublines(img,avglines):
    sublines = []
    for line in avglines:
        slope,b=line
        y1=img.shape[0]
        y2 = int(y1*(3/5))
        y1=int(y1*(11/15))
        x1 =int((y1-b)/slope)
        x2 =int((y2-b)/slope)
        
        sublines.append([x1,y1,x2,y2])
    return np.array(sublines)
img = cv2.imread('d:/road.jpg')
edge = get_edge(img)
roi = get_roi(edge)
lines = cv2.HoughLinesP(image=roi,
                       rho=3,
                       theta=np.pi/180,
                       threshold=60,
                       minLineLength = 40,
                       maxLineGap = 50)
avglines = get_avglines(lines)
if avglines is not None:
    lines = get_sublines(img,avglines)
    img = draw_lines(img,lines) 
    cv2.imshow('Line',img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
#EXERCISE
import cv2
import numpy as np
def get_edge(img):
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray,(13,13),0)
    canny = cv2.Canny(blur,50,150)
    return canny
def get_roi(img):
    mask = np.zeros_like(img)
    points=np.array([[[146,539],[781,539],[515,417],[296,397]]])
    cv2.fillPoly(mask,points,255)
    roi=cv2.bitwise_and(img,mask)
    return roi
def draw_lines(img,lines):
    for line in lines:
        points = line.reshape(4,)
        x1,y1,x2,y2=points
        cv2.line(img,(x1,y1),(x2,y2),(0,0,255),3)
    return img
def get_avglines(lines):
    if lines is None:
        print('Cannot detect straight line segment')
        return None
    lefts=[]
    rights=[]
    for line in lines:
        points = line.reshape(4,)
        x1,y1,x2,y2=points
        slope,b=np.polyfit((x1,x2),(y1,y2),1)
        if slope>0:
            rights.append([slope,b])
        else:
             lefts.append([slope,b])
    if rights and lefts:
        right_avg = np.average(rights,axis=0)
        left_avg = np.average(lefts,axis=0)
        return np.array([right_avg,left_avg])
    else:
        print('Cannot detect two lines simultaneously')
        return None
def get_sublines(img,avglines):
    sublines = []
    for line in avglines:
        slope,b=line
        y1=img.shape[0]
        y2 = int(y1*(3/5))
        y1=int(y1*(11/15))
        x1 =int((y1-b)/slope)
        x2 =int((y2-b)/slope)
        
        sublines.append([x1,y1,x2,y2])
    return np.array(sublines)
capture = cv2.VideoCapture('d:/road.mp4')
if capture.isOpened:
    while True:
        success,img=capture.read()
        if success:
            edge=get_edge(img)
            roi = get_roi(edge)
            lines = cv2.HoughLinesP(image=roi,
                                   rho=3,
                                   theta=np.pi/180,
                                   threshold=30,
                                   minLineLength = 50,
                                   maxLineGap = 40)
            avglines = get_avglines(lines)
            if avglines is not None:
                lines = get_sublines(img,avglines)
                img = draw_lines(img,lines) 
            cv2.imshow('Frame',img)
        k=cv2.waitKey(1)
        if k==ord('q') or k==ord('Q'):
            print('exit')
            cv2.destroyAllWindows()    
            capture.release()
            break
else:
    print('Fail to open camera')
# Out:
# exit

# %%
#EXERCISE
import cv2
import numpy as np
def get_edge(img):
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray,(13,13),0)
    canny = cv2.Canny(blur,50,150)
    return canny
def get_roi(img):
    mask = np.zeros_like(img)
    points=np.array([[[146,539],[781,539],[515,417],[296,397]]])
    cv2.fillPoly(mask,points,255)
    roi=cv2.bitwise_and(img,mask)
    return roi
def draw_lines(img,lines):
    for line in lines:
        points = line.reshape(4,)
        x1,y1,x2,y2=points
        cv2.line(img,(x1,y1),(x2,y2),(0,0,255),3)
    return img
def get_avglines(lines):
    if lines is None:
        print('Cannot detect straight line segment')
        return None
    lefts=[]
    rights=[]
    for line in lines:
        points = line.reshape(4,)
        x1,y1,x2,y2=points
        slope,b=np.polyfit((x1,x2),(y1,y2),1)
        if slope>0:
            rights.append([slope,b])
        else:
             lefts.append([slope,b])
    if rights and lefts:
        right_avg = np.average(rights,axis=0)
        left_avg = np.average(lefts,axis=0)
        return np.array([right_avg,left_avg])
    else:
        print('Cannot detect two lines simultaneously')
        return None
def get_sublines(img,avglines):
    sublines = []
    for line in avglines:
        slope,b=line
        y1=img.shape[0]
        y2 = int(y1*(3/5))
        y1=int(y1*(11/15))
        x1 =int((y1-b)/slope)
        x2 =int((y2-b)/slope)
        
        sublines.append([x1,y1,x2,y2])
    return np.array(sublines)
capture = cv2.VideoCapture('d:/road2.mp4')
if capture.isOpened:
    while True:
        success,img=capture.read()
        if success:
            edge=get_edge(img)
            roi = get_roi(edge)
            lines = cv2.HoughLinesP(image=roi,
                                   rho=3,
                                   theta=np.pi/180,
                                   threshold=30,
                                   minLineLength = 50,
                                   maxLineGap = 40)
            avglines = get_avglines(lines)
            if avglines is not None:
                lines = get_sublines(img,avglines)
                img = draw_lines(img,lines) 
            cv2.imshow('Frame',img)
        k=cv2.waitKey(0)
        if k==ord('q') or k==ord('Q'):
            print('exit')
            cv2.destroyAllWindows()    
            capture.release()
            break
else:
    print('Fail to open camera')
